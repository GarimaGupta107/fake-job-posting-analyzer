# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Data Loading

# %%
df=pd.read_csv("fake_job_postings.csv")
df
# Out:
#        job_id                                              title  \
# 0           1                                   Marketing Intern
# 1           2          Customer Service - Cloud Video Production
# 2           3            Commissioning Machinery Assistant (CMA)
# 3           4                  Account Executive - Washington DC
# 4           5                                Bill Review Manager
# ...       ...                                                ...
# 17875   17876                   Account Director - Distribution
# 17876   17877                                 Payroll Accountant
# 17877   17878  Project Cost Control Staff Engineer - Cost Con...
# 17878   17879                                   Graphic Designer
# 17879   17880                         Web Application Developers
#
#                    location   department salary_range  \
# 0          US, NY, New York    Marketing          NaN
# 1            NZ, , Auckland      Success          NaN
# ...

# %% [markdown]
# ## First 10 Rows

# %%
df.head(10)
# Out:
#    job_id                                      title               location  \
# 0       1                           Marketing Intern       US, NY, New York
# 1       2  Customer Service - Cloud Video Production         NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)          US, IA, Wever
# 3       4          Account Executive - Washington DC     US, DC, Washington
# 4       5                        Bill Review Manager     US, FL, Fort Worth
# 5       6                           Accounting Clerk               US, MD,
# 6       7                      Head of Content (m/f)         DE, BE, Berlin
# 7       8           Lead Guest Service Specialist     US, CA, San Francisco
# 8       9                                 HP BSM SME      US, FL, Pensacola
# 9      10    Customer Service Associate - Part Time         US, AZ, Phoenix
#
#    department salary_range                                    company_profile  \
# ...

# %% [markdown]
# ## Last 10 Rows

# %%
df.tail(10)
# Out:
#        job_id                                              title  \
# 17870   17871                 Senior Financial Analyst (Retail)
# 17871   17872                                 Water Truck Driver
# 17872   17873                                    Product Manager
# 17873   17874                             Recruiting Coordinator
# 17874   17875                               JavaScript Developer
# 17875   17876                   Account Director - Distribution
# 17876   17877                                 Payroll Accountant
# 17877   17878  Project Cost Control Staff Engineer - Cost Con...
# 17878   17879                                   Graphic Designer
# 17879   17880                         Web Application Developers
#
#                     location           department  salary_range  \
# 17870        US, CA, Gardena                  NaN           NaN
# 17871     US, PA, Waynesburg                  NaN           NaN
# ...

# %% [markdown]
# ## Random 10 Rows

# %%
df.sample(10)
# Out:
#        job_id                                              title  \
# 1785     1786            Business Development Intern (Full Time)
# 9729     9730               Executive Assistant / Office Manager
# 9279     9280                        Customer Service Associate
# 1200     1201  Business Development Director  - Fashion Weara...
# 9658     9659                                         Controller
# 11724   11725                                JAVA/J2EE developer
# 9986     9987                    Continuous Improvement Engineer
# 3553     3554                                 Marketing Director
# 1877     1878                        Customer Service Associate
# 11150   11151                          Administrative Assistant
#
#                     location                    department salary_range  \
# 1785           GR, I, Athens                           NaN          NaN
# 9729          GB, LDS, Leeds                           NaN  27000-32000
# ...

# %% [markdown]
# ## Columns

# %%
df.columns
# Out:
# Index(['job_id', 'title', 'location', 'department', 'salary_range',
#        'company_profile', 'description', 'requirements', 'benefits',
#        'telecommuting', 'has_company_logo', 'has_questions', 'employment_type',
#        'required_experience', 'required_education', 'industry', 'function',
#        'fraudulent'],
#       dtype='object')

# %% [markdown]
# ## Statistical Summary

# %%
df.describe()
# Out:
#              job_id  telecommuting  has_company_logo  has_questions  \
# count  17880.000000   17880.000000      17880.000000   17880.000000
# mean    8940.500000       0.042897          0.795302       0.491723
# std     5161.655742       0.202631          0.403492       0.499945
# min        1.000000       0.000000          0.000000       0.000000
# 25%     4470.750000       0.000000          1.000000       0.000000
# 50%     8940.500000       0.000000          1.000000       0.000000
# 75%    13410.250000       0.000000          1.000000       1.000000
# max    17880.000000       1.000000          1.000000       1.000000
#
#          fraudulent
# count  17880.000000
# mean       0.048434
# std        0.214688
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %% [markdown]
# ## Datatype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17880 entries, 0 to 17879
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_id               17880 non-null  int64
#  1   title                17880 non-null  object
#  2   location             17534 non-null  object
#  3   department           6333 non-null   object
#  4   salary_range         2868 non-null   object
#  5   company_profile      14572 non-null  object
#  6   description          17879 non-null  object
#  7   requirements         15184 non-null  object
#  8   benefits             10668 non-null  object
#  9   telecommuting        17880 non-null  int64
#  10  has_company_logo     17880 non-null  int64
#  11  has_questions        17880 non-null  int64
#  12  employment_type      14409 non-null  object
#  13  required_experience  10830 non-null  object
#  14  required_education   9775 non-null   object
# ...

# %% [markdown]
# ## Shape

# %%
df.shape
# Out:
# (17880, 18)

# %% [markdown]
# ## Null Values

# %%
df.isnull().sum()
# Out:
# job_id                     0
# title                      0
# location                 346
# department             11547
# salary_range           15012
# company_profile         3308
# description                1
# requirements            2696
# benefits                7212
# telecommuting              0
# has_company_logo           0
# has_questions              0
# employment_type         3471
# required_experience     7050
# required_education      8105
# industry                4903
# function                6455
# fraudulent                 0
# dtype: int64

# %% [markdown]
# ## Duplicate Values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Fraud Jobs

# %%
counts =df['fraudulent'].value_counts()
print("Genuine Jobs (0):", counts[0])
print("Fake Jobs (1):", counts[1])
# Out:
# Genuine Jobs (0): 17014
# Fake Jobs (1): 866
